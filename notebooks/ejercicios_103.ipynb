# %% [markdown]
# ## Python para Data Science: Primeros Pasos.
# ### Aula 1: Estructuras condicionales.

# %% [markdown]
# **Entrenando la programación:**

# %% [markdown]
# 1 - Escribe un programa que pida a la persona usuaria que proporcione dos números y muestre el número más grande.

# %%
num_1 = int(input("Ingrese primer número"))
num_2 = int(input("Ingrese segundo número"))

if num_1 > num_2:
    print(f"{num_1} es mayor que {num_2}")
elif num_1 < num_2:
    print(f"{num_2} es mayor que {num_1}")
else:
    print("Ambos números son iguales.")
# Out:
# 15 es mayor que 10

# %% [markdown]
# 2 - Escribe un programa que solicite el porcentaje de crecimiento de producción de una empresa e informe si hubo un crecimiento (porcentaje positivo) o una disminución (porcentaje negativo).

# %%
variacion = int(input("Ingrese el porcentaje de crecimiento (positivo o negativo):"))

if variacion > 0:
    print(f"El porcentaje de crecimiento aumentó en {variacion}%")
elif variacion < 0:
    print(f"El porcentaje de crecimiento disminuyó en {variacion}%")
else:
    print("No se registró variación en el periodo.")
# Out:
# El porcentaje de crecimiento disminuyó en -30%

# %% [markdown]
# 3 - Escribe un programa que determine si una letra proporcionada por la persona usuaria es una vocal o una consonante.

# %%
letra = input("Ingrese una letra para determinar si es consonante o vocal").lower()

if len(letra) != 1 or not letra.isalpha():
    print("Por favor, ingrese solo UNA letra")
elif letra in "aeiou":
    print(f"Letra {letra} es vocal")
else:
    print(f"Letra {letra} es consonante")
# Out:
# Letra a es vocal

# %% [markdown]
# 4 - Escribe un programa que lea valores promedio de precios de un modelo de automóvil durante 3 años consecutivos y muestre el valor más alto y más bajo entre esos tres años.

# %%
precios = []

for i in range(1, 4):
    precio = int(input(f"Ingresa el precio promedio del año {i}"))
    print(f"Precio promedio del año {i} es: ${precio}")
    precios.append(precio)

print(f"El precio más alto fue: ${max(precios)}")
print(f"El precio más bajo fue: ${min(precios)}")
# Out:
# Precio promedio del año 1 es: $1500
# Precio promedio del año 2 es: $2800
# Precio promedio del año 3 es: $2000
# El precio más alto fue: $2800
# El precio más bajo fue: $1500

# %% [markdown]
# 5 - Escribe un programa que pregunte sobre el precio de tres productos e indique cuál es el producto más barato para comprar.

# %%
precios = []

for i in range(1, 4):
    precio = int(input(f"Ingrese el precio del producto {i}"))
    print(f"Precio de producto {i}: ${precio}")
    precios.append(precio)

mensajes = [
    "El primer producto es el más barato",
    "El segundo producto es el más barato",
    "El tercer producto es el más barato"
]

indice = precios.index(min(precios))
print(f"{mensajes[indice]}, con un precio de ${precios[indice]}")
# Out:
# Precio de producto 1: $900
# Precio de producto 2: $800
# Precio de producto 3: $70000
# El segundo producto es el más barato, con un precio de $800

# %% [markdown]
# 6 - Escribe un programa que lea tres números y los muestre en orden descendente.

# %%
numeros = []

for i in range(1, 4):
    numero = int(input(f"Ingrese el número {i}:"))
    numeros.append(numero)

numeros.sort(reverse=True)

print(f"Numeros en orden descendente: {numeros}")
# Out:
# Numeros en orden descendente: [15, 8, 4]

# %% [markdown]
# 7 -Escribe un programa que pregunte en qué turno estudia la persona usuaria ("mañana", "tarde" o "noche") y muestre el mensaje "¡Buenos Días!", "¡Buenas Tardes!", "¡Buenas Noches!" o "Valor Inválido!", según el caso.

# %%
turno = input("¿En que turno estudias?(mañana/tarde/noche) ").strip().lower()

saludos = {
    "mañana" : "¡Buenos Días!",
    "tarde"  : "¡Buenas Tardes!",
    "noche"  : "¡Buenas Noches!"
}

# En un diccionario (saludos), el metodo get() intenta buscar una clave
# En caso de no encontrarlo, devuelve el segundo arg por default
print(saludos.get(turno, "¡Valor Inválido!"))
# Out:
# ¡Buenos Días!

# %% [markdown]
# 8 - Escribe un programa que solicite un número entero a la persona usuaria y determine si es par o impar. Pista: Puedes usar el operador módulo (%).

# %%
try:
    num = int(input("Ingrese un número:"))
    if num % 2 == 0:
        print(f"{num} es par")
    else:
        print(f"{num} es impar")
except ValueError:
    print("Ingrese valor válido")
# Out:
# Ingrese valor válido

# %% [markdown]
# 9 - Escribe un programa que pida un número a la persona usuaria y le informe si es entero o decimal.

# %%
try:
    numero = float(input("Ingrese un número: "))

    if numero.is_integer():
        print(f"{numero} es un número entero.")
    else:
        print(f"{numero} es un número decimal.")
except ValueError:
    print("Ingrese un valor válido (sólo números)")
# Out:
# Ingrese un valor válido (sólo números)

# %% [markdown]
# **Momento de los proyectos:**

# %% [markdown]
# 10 - Un programa debe ser escrito para leer dos números y luego preguntar a la persona usuaria qué operación desea realizar. El resultado de la operación debe incluir información sobre el número, si es par o impar, positivo o negativo, e entero o decimal.

# %%
import math

# Iniciamos un array donde almacenar los números
numeros = []

# Ciclo while con un try/except que pide los números al usuario
# y valida que sean correctos antes de agregarlos al array
while True:
    try:
        for i in range(2):
            numero = float(input(f"Ingrese numero {i + 1}"))
            numeros.append(numero)
        break

    except ValueError:
        print("Ingrese un valor válido (solo números)")


# Pedimos al usuario la operación que desea realizar
calculo = input("Seleccione operacion: suma (+), resta (-), multiplicación(*), división(/)").strip()

resultado = None #Inicializamos resultado en None

# Gestionamos la operación:
if calculo == '+':
    resultado = sum(numeros)
elif calculo == '-':
    resultado = numeros[0] - numeros[1]
elif calculo == '*':
    resultado = math.prod(numeros)
elif calculo == '/':
    if numeros[1] == 0:
        print("No se puede realizar una división por cero")
    else:
        resultado = numeros[0] / numeros [1]
else:
    print("Ingrese una opción válida(+,-,* ó /)")

# Mostrar resultado si existe:
if resultado is not None:

    caracteristicas = [] # Array para almacenar la descripción del número

    # Positivo o negativo:    
    if resultado > 0:
        caracteristicas.append("positivo")
    elif resultado < 0:
        caracteristicas.append("negativo")
    else:
        caracteristicas.append("cero")

    # Entero o decimal:
    if float(resultado).is_integer():
        caracteristicas.append("entero")
        
        # Par o impar solo si es entero
        if int(resultado) % 2 == 0:
            caracteristicas.append("par")
        else:
            caracteristicas.append("impar")
    
    else:
        caracteristicas.append("decimal")

    # Resultados
    print(f"El resultado de {numeros[0]} {calculo} {numeros[1]} es {resultado} ")
    print(f"El número resultante es {', '.join(caracteristicas)}.\n")
# Out:
# El resultado de 5 / 2 es 2.5
# El número resultante es positivo, decimal.

# %% [markdown]
# 11 - Escribe un programa que pida a la persona usuaria tres números que representan los lados de un triángulo. El programa debe informar si los valores pueden utilizarse para formar un triángulo y, en caso afirmativo, si es equilátero, isósceles o escaleno. Ten en cuenta algunas sugerencias:
#
# - Tres lados forman un triángulo cuando la suma de cualesquiera dos lados es mayor que el tercero;
# - Triángulo Equilátero: tres lados iguales;
# - Triángulo Isósceles: dos lados iguales;
# - Triángulo Escaleno: tres lados diferentes.

# %%
# Usamos un array para almacenar valores:
lados = []

# Usamos un ciclo for con range(inicio, final[no incluido])
# Es decir, la enumeración va del i[1] al i[3] para mejor entendimiento.
for i in range(1, 4):
    while True:
        try:
            lado = float(input(f"Ingrese el lado {i}:").strip())
            lados.append(lado)
            break
        except ValueError:
            print("Ingrese un valor válido (números)")

# Desestructuramos el array, es decir a = lados[0], b = lados[1], c = lados[2]

print(lados)

a, b, c = lados

# Verificamos si se puede armar un triángulo con los valores ingresados
if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("Con los valores ingresados se puede armar un triángulo equilátero.")
    elif a == b or a == c or b == c:
        print("Con los valores ingresados se puede armar un triángulo isósceles.")
    else:
        print("Con los valores ingresados se puede armar un triángulo escaleno.")
else:
    print("Los valores no forman un triángulo. \n")
# Out:
# [5.0, 5.0, 5.0]
# Con los valores ingresados se puede armar un triángulo equilátero.

# %% [markdown]
# 12 - Un establecimiento está vendiendo combustibles con descuentos variables. Para el etanol, si la cantidad comprada es de hasta 15 litros, el descuento será del 2% por litro. En caso contrario, será del 4% por litro. Para el diésel, si la cantidad comprada es de hasta 15 litros, el descuento será del 3% por litro. En caso contrario, será del 5% por litro. El precio por litro de diésel es de R$ 2,00 y el precio por litro de etanol es de R$ 1,70. Escribe un programa que lea la cantidad de litros vendidos y el tipo de combustible (E para etanol y D para diésel) y calcule el valor a pagar por el cliente. Ten en cuenta algunas sugerencias:
#
#  - El valor del descuento será el producto del precio por litro, la cantidad de litros y el valor del descuento.
#  - El valor a pagar por un cliente será el resultado de la multiplicación del precio por litro por la cantidad de litros menos el valor del descuento resultante del cálculo.

# %%
tipo_combustible = input("Seleccione el tipo de combustible: etanol(E)/ diesel (D)").upper().strip()
print(tipo_combustible)

# Establecemos el precio por litro de acuerdo al tipo de combustible
if tipo_combustible == 'E':
    precio_litro = 1.70
   
elif tipo_combustible == 'D':
    precio_litro = 2.00

else:
    print("Ingrese un tipo válido de combustible")
    exit() # Detenemos el programa si no es válido

# Ingresamos los litros y calculamos el total de venta
litros = float(input("Ingrese los litros a comprar:"))
total_venta = precio_litro * litros

# Calcular descuento una sola vez

if tipo_combustible == 'E':
    # Calculamos el descuento usando un if ternario
    descuento = total_venta * (0.02 if litros <= 15 else 0.04)
else:
    descuento = total_venta * (0.03 if litros <= 15 else 0.05)

# Calculamos el total a pagar:
total_pagar = total_venta - descuento

# Mostramos el resultado:
print(f"Total: R${total_pagar:.2f} (descuento de R${descuento:.2f})")
# Out:
# D
# Total: R$34.20 (descuento de R$1.80)

# %% [markdown]
# 13 - En una empresa de venta de bienes raíces, debes crear un código que analice los datos de ventas anuales para ayudar a la dirección en la toma de decisiones. El código debe recopilar los datos de cantidad de ventas durante los años 2022 y 2023 y calcular la variación porcentual. A partir del valor de la variación, se deben proporcionar las siguientes sugerencias:
#
#  - Para una variación superior al 20%: bonificación para el equipo de ventas.
#  - Para una variación entre el 2% y el 20%: pequeña bonificación para el equipo de ventas.
#  - Para una variación entre el 2% y el -10%: planificación de políticas de incentivo a las ventas.
#  - Para bonificaciones inferiores al -10%: recorte de gastos.

# %%
# Solicitar los datos de venta para 2022 y 2023
while True:
    try:
        ventas_2022 = float(input("Ingrese el total de ventas del año 2022:"))
        ventas_2023 = float(input("Ingrese el total de ventas del año 2023:"))
        break
    except ValueError:
        print("Ingrese valores numéricos válidos.")

# Calcular variación porcentual:
variacion = ((ventas_2023 - ventas_2022) / ventas_2022) * 100

print(f"\nVariación porcentual: {variacion:.2f}%")

# Evaluar rango y mostrar sugerencia:
if variacion > 20:
    print("Recomendación: Bonificación para el equipo de venta")
elif 2 <= variacion <= 20:
    print("Recomendación: Pequeña bonificación para el equipo de ventas")
elif -10 <= variacion < 2:
    print("Recomendación: Planificación de políticas de incentivo a las ventas")
else:
    print("Recomendación: Recorte de gastos.")
# Out:
# Variación porcentual: 94.44%
# Recomendación: Bonificación para el equipo de venta
