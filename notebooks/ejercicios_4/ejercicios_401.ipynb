# %% [markdown]
# ## Numpy: Análisis numérico eficiente con Python.
# ### Aula 1: Conociendo Numpy.

# %% [markdown]
# - Importar Numpy

# %%
# Importo la libreria
import numpy as np

# Verifico si está instalada preguntando la versión
print(np.__version__)
# Out:
# 2.3.4

# %% [markdown]
# - Importar el dataset desde un csv

# %%
# Almaceno la url en una variable
url = '../../data/citrus.csv'

datos = np.loadtxt(
    url,
    delimiter=',',
    skiprows=1,
    usecols=np.arange(1,6)
)

datos
# Out:
# array([[  2.96,  86.76, 172.  ,  85.  ,   2.  ],
#        [  3.91,  88.05, 166.  ,  78.  ,   3.  ],
#        [  4.42,  95.17, 156.  ,  81.  ,   2.  ],
#        ...,
#        [ 15.59, 256.5 , 168.  ,  82.  ,  20.  ],
#        [ 15.92, 260.14, 142.  ,  72.  ,  11.  ],
#        [ 16.45, 261.51, 152.  ,  74.  ,   2.  ]], shape=(10000, 5))

# %%
datos.ndim
# Out:
# 2

# %%
datos.shape
# Out:
# (10000, 5)
